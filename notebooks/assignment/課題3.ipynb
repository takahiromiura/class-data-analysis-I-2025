# %% [markdown]
# # 課題に関する注意
#
# - 元のセルは削除しないでください
# - 左上に `ファイル 編集` などが表示されていない場合、ヘッダーを表示する必要があります。 画面右上の下向きのアイコンを押すと、ヘッダーが表示されます。 非表示にするには上向きのアイコンを押します。
# - 提出用のファイルは、`ファイル -> ダウンロード -> .ipynb をダウンロード` でダウンロードします (.py ファイルではありません)。
# - ファイル提出前に `ランタイム -> セッションを再起動して全て実行する` を行い、結果を保存したものを提出してください。
# - 問題に関係のないコードが含まれている場合、減点対象になります。
# - 最後まで実行できないファイルは評価対象外です。

# %% [markdown]
# # 課題 3
#
# 以下は、Stack Overflow の API を使って取得した解答データを一部除外・整形したものです ([元データのリンク](https://api.stackexchange.com/docs/answers#fromdate=2025-06-01&todate=2025-06-02&order=desc&sort=activity&filter=default&site=stackoverflow&run=true))。
#
# 解答オブジェクトのドキュメントページ: https://api.stackexchange.com/docs/types/answer
#
# このデータを使った分析を行ってください。

# %%
data = {
  "items": [
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647333,
      "question_id": 77854001,
      "owner": {
        "account_id": 11916026,
        "reputation": 11,
        "user_id": 8719898,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 1,
      "answer_id": 79647692,
      "question_id": 79647617,
      "owner": {
        "account_id": 16860149,
        "reputation": 161,
        "user_id": 12191150,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 1,
      "answer_id": 79647801,
      "question_id": 79647523,
      "owner": {
        "account_id": 329584,
        "reputation": 4456,
        "user_id": 653182,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 1,
      "answer_id": 79647116,
      "question_id": 79646230,
      "owner": {
        "account_id": 1167427,
        "reputation": 25697,
        "user_id": 1145388,
        "user_type": "moderator",
        "accept_rate": 75
      }
    },
    {
      "is_accepted": "false",
      "score": 2,
      "answer_id": 79648005,
      "question_id": 46374357,
      "owner": {
        "account_id": 414922,
        "reputation": 412,
        "user_id": 3182021,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 0,
      "answer_id": 79647668,
      "question_id": 79647629,
      "owner": {
        "account_id": 37047612,
        "reputation": 11,
        "user_id": 28050274,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 5,
      "answer_id": 79647915,
      "question_id": 79647880,
      "owner": {
        "account_id": 16907258,
        "reputation": 22222,
        "user_id": 12545041,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 1,
      "answer_id": 79647775,
      "question_id": 79647745,
      "owner": {
        "account_id": 308139,
        "reputation": 13506,
        "user_id": 619830,
        "user_type": "registered",
        "accept_rate": 75
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79648018,
      "question_id": 79647980,
      "owner": {
        "account_id": 1119904,
        "reputation": 375,
        "user_id": 1108473,
        "user_type": "registered",
        "accept_rate": 71
      }
    },
    {
      "is_accepted": "true",
      "score": 1,
      "answer_id": 79647243,
      "question_id": 79633655,
      "owner": {
        "account_id": 65698,
        "reputation": 20127,
        "user_id": 193178,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 5,
      "answer_id": 79647810,
      "question_id": 79647727,
      "owner": {
        "account_id": 64461,
        "reputation": 229467,
        "user_id": 190277,
        "user_type": "registered",
        "accept_rate": 94
      }
    },
    {
      "is_accepted": "true",
      "score": 3,
      "answer_id": 79647458,
      "question_id": 79646994,
      "owner": {
        "account_id": 3010725,
        "reputation": 45982,
        "user_id": 2554330,
        "user_type": "registered",
        "accept_rate": 71
      }
    },
    {
      "is_accepted": "true",
      "score": 0,
      "answer_id": 79647084,
      "question_id": 79643497,
      "owner": {
        "account_id": 1840660,
        "reputation": 52966,
        "user_id": 1670129,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647120,
      "question_id": 79647082,
      "owner": {
        "account_id": 24172783,
        "reputation": 1294,
        "user_id": 21440243,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 0,
      "answer_id": 79647939,
      "question_id": 79641902,
      "owner": {
        "account_id": 10070332,
        "reputation": 32780,
        "user_id": 7444103,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647754,
      "question_id": 2095394,
      "owner": {
        "account_id": 17360131,
        "reputation": 1520,
        "user_id": 12576620,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 1,
      "answer_id": 79647777,
      "question_id": 77038519,
      "owner": {
        "account_id": 5117078,
        "reputation": 11,
        "user_id": 4101851,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 5,
      "answer_id": 79647679,
      "question_id": 79647481,
      "owner": {
        "account_id": 10929,
        "reputation": 565145,
        "user_id": 20860,
        "user_type": "registered",
        "accept_rate": 92
      }
    },
    {
      "is_accepted": "false",
      "score": -1,
      "answer_id": 79648037,
      "question_id": 73151033,
      "owner": {
        "account_id": 41035884,
        "reputation": 1,
        "user_id": 30087492,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 1,
      "answer_id": 79647881,
      "question_id": 79647182,
      "owner": {
        "account_id": 10096950,
        "reputation": 16901,
        "user_id": 7462031,
        "user_type": "registered",
        "accept_rate": 50
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647603,
      "question_id": 79645276,
      "owner": {
        "account_id": 75457,
        "reputation": 20101,
        "user_id": 216440,
        "user_type": "registered",
        "accept_rate": 90
      }
    },
    {
      "is_accepted": "true",
      "score": 1,
      "answer_id": 79647461,
      "question_id": 79647341,
      "owner": {
        "account_id": 26585047,
        "reputation": 174,
        "user_id": 20209097,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647604,
      "question_id": 79647531,
      "owner": {
        "account_id": 40802606,
        "reputation": 1,
        "user_id": 29960941,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 1,
      "answer_id": 79647854,
      "question_id": 79647456,
      "owner": {
        "account_id": 2375785,
        "reputation": 4909,
        "user_id": 2079189,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": -3,
      "answer_id": 79647816,
      "question_id": 79647768,
      "owner": {
        "account_id": 22152062,
        "reputation": 60,
        "user_id": 16400435,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647222,
      "question_id": 79625458,
      "owner": {
        "account_id": 2782753,
        "reputation": 3871,
        "user_id": 2394945,
        "user_type": "registered",
        "accept_rate": 83
      }
    },
    {
      "is_accepted": "true",
      "score": 4,
      "answer_id": 79647612,
      "question_id": 79647545,
      "owner": {
        "account_id": 22226004,
        "reputation": 17963,
        "user_id": 16462950,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "true",
      "score": 0,
      "answer_id": 79648042,
      "question_id": 79647944,
      "owner": {
        "account_id": 41856352,
        "reputation": 679,
        "user_id": 30481796,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 0,
      "answer_id": 79647129,
      "question_id": 3068091,
      "owner": {
        "account_id": 7743199,
        "reputation": 276,
        "user_id": 6243733,
        "user_type": "registered"
      }
    },
    {
      "is_accepted": "false",
      "score": 3,
      "answer_id": 79647783,
      "question_id": 79647691,
      "owner": {
        "account_id": 3427552,
        "reputation": 61162,
        "user_id": 2872922,
        "user_type": "registered",
        "accept_rate": 54
      }
    }
  ],
  "has_more": "true",
  "quota_max": 10000,
  "quota_remaining": 9978
}

# %% [markdown]
# ## 問 1
#
# `data` から、解答データのリストを取り出したものを、`answers` という変数に格納してください。
#
# 以降は、この `answers` を使って分析を行ってください。

# %% [markdown]
# ## 問 2
#
# いくつの解答 (オブジェクト) がデータに含まれていますか。
#
# 結果を出力してください。

# %% [markdown]
# ## 問 3
#
# 解答の平均スコア (`score`) を計算して、結果を出力してください。
#
# ループ処理を用いること。

# %% [markdown]
# ## 問 4
#
# `answers` を入れると回答の平均スコアを計算し、その値を返す関数 `mean_score` を作成してください。
#
# また、`mean_score` を実行して、その結果を出力してください。

# %% [markdown]
# ## 問 5
#
# 解答を行ったユーザー (解答者) の平均評価スコア (`reputation`) を計算して、結果を出力してください。

# %% [markdown]
# ## 問 6
#
# 解答の平均受諾率を計算して、結果を出力してください。
#
# 解答が受諾されたかどうかは、`is_accept` に記載されています。
#
# 受諾された場合は `is_accept` は `true`、それ以外では `false` の値を取ります。
#
# また、受諾率は 0 から 1 の値を取ります (100% なら 1)。
